# %%
#1. Read the dataset as a dataframe. Create a copy of your dataframe. 
# Solve the rest of the questions using this dataframe copy.

import pandas as pd
import numpy as np
weather=pd.read_csv('weatherAUS.csv')
df=weather.copy()
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
#2. Find out the describe and info attributes of the dataframe. 
# Analyze these information and create a short write-up according to your findings.
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
#3. Find out the shape and size info of the dataset.
print(df.shape)
print(df.size)
# Out:
# (145460, 23)
# 3345580

# %%
#4. Find out the types values of the columns and save the result as a dataframe.
df_dtpes=pd.DataFrame(df.dtypes, columns=['dtype'])
df_dtpes
# Out:
#                  dtype
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %%
#5. Find out the non-null counts of the columns and save the result as a dataframe.
nonnull=pd.DataFrame(df.notnull().sum(),columns=['nonnull'])
nonnull
# Out:
#                nonnull
# Date            145460
# Location        145460
# MinTemp         143975
# MaxTemp         144199
# Rainfall        142199
# Evaporation      82670
# Sunshine         75625
# WindGustDir     135134
# WindGustSpeed   135197
# WindDir9am      134894
# WindDir3pm      141232
# WindSpeed9am    143693
# WindSpeed3pm    142398
# Humidity9am     142806
# Humidity3pm     140953
# Pressure9am     130395
# Pressure3pm     130432
# Cloud9am         89572
# Cloud3pm         86102
# Temp9am         143693
# Temp3pm         141851
# RainToday       142199
# RainTomorrow    142193

# %%
#6. Find out the null counts of the columns and save the result as a dataframe.
null=pd.DataFrame(df.isnull().sum(),columns=['null'])
null
# Out:
#                 null
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# Evaporation    62790
# Sunshine       69835
# WindGustDir    10326
# WindGustSpeed  10263
# WindDir9am     10566
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Pressure9am    15065
# Pressure3pm    15028
# Cloud9am       55888
# Cloud3pm       59358
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267

# %%
#7. Find out the unique counts of the columns and save the result as a dataframe.
unique=pd.DataFrame(df.nunique(),columns=['unique'])
unique
# Out:
#                unique
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          681
# Evaporation       358
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           441
# Temp3pm           502
# RainToday           2
# RainTomorrow        2

# %%
#8. Merge the dataframes you created in questions 4-5-6-7. Expected output: example result
#,null,unique
df_merge1=pd.merge(df_dtpes,nonnull,left_index=True,right_index=True)
df_merge2=pd.merge(df_merge1,null,left_index=True,right_index=True)
df_merge=pd.merge(df_merge2,unique,left_index=True,right_index=True)
df_merges=pd.DataFrame(df_merge)
df_merges
# Out:
#                  dtype  nonnull   null  unique
# Date            object   145460      0    3436
# Location        object   145460      0      49
# MinTemp        float64   143975   1485     389
# MaxTemp        float64   144199   1261     505
# Rainfall       float64   142199   3261     681
# Evaporation    float64    82670  62790     358
# Sunshine       float64    75625  69835     145
# WindGustDir     object   135134  10326      16
# WindGustSpeed  float64   135197  10263      67
# WindDir9am      object   134894  10566      16
# WindDir3pm      object   141232   4228      16
# WindSpeed9am   float64   143693   1767      43
# WindSpeed3pm   float64   142398   3062      44
# Humidity9am    float64   142806   2654     101
# Humidity3pm    float64   140953   4507     101
# Pressure9am    float64   130395  15065     546
# Pressure3pm    float64   130432  15028     549
# Cloud9am       float64    89572  55888      10
# Cloud3pm       float64    86102  59358      10
# Temp9am        float64   143693   1767     441
# Temp3pm        float64   141851   3609     502
# RainToday       object   142199   3261       2
# RainTomorrow    object   142193   3267       2

# %%
#9. Lowercase all column names.
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %%
#10. Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

df['raintoday'].replace('No','NoRain',inplace=True)
df['raintoday'].replace('Yes','Rain', inplace=True)
df['raintomorrow'].replace('No','NoRain', inplace=True)
df['raintomorrow'].replace('Yes','Rain', inplace=True)
print(df['raintoday'])
print(df['raintomorrow'])
# Out:
# 0         NoRain
# 1         NoRain
# 2         NoRain
# 3         NoRain
# 4         NoRain
#            ...
# 145455    NoRain
# 145456    NoRain
# 145457    NoRain
# 145458    NoRain
# 145459    NoRain
# Name: raintoday, Length: 145460, dtype: object
# 0         NoRain
# 1         NoRain
# 2         NoRain
# 3         NoRain
# 4         NoRain
#            ...
# 145455    NoRain
# 145456    NoRain
# 145457    NoRain
# 145458    NoRain
# 145459       NaN
# Name: raintomorrow, Length: 145460, dtype: object

# %%
#11. Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.
print(df['date'].info())
df['date']=df['date'].astype('datetime64[ns]')
df['date']=df['date'].dt.strftime('%d/%m/%Y')
df['date']
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 145460 entries, 0 to 145459
# Series name: date
# Non-Null Count   Dtype
# --------------   -----
# 145460 non-null  object
# dtypes: object(1)
# memory usage: 1.1+ MB
# None
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/12/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/01/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/02/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/03/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/04/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/05/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/06/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/07/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/08/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/09/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/10/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/11/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/11/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/12/2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '13/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '14/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '15/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '16/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '17/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '18/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '19/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '20/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '21/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '22/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '23/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '24/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '25/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '26/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '27/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '28/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '29/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '30/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# c:\Users\hasan\myworkspace\python\WEEKS\.venv\lib\site-packages\pandas\core\dtypes\cast.py:1163: UserWarning: Parsing '31/01/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   to_datetime(arr).values,
# 0         12/01/2008
# 1         12/02/2008
# 2         12/03/2008
# 3         12/04/2008
# 4         12/05/2008
#              ...
# 145455    21/06/2017
# 145456    22/06/2017
# 145457    23/06/2017
# 145458    24/06/2017
# 145459    25/06/2017
# Name: date, Length: 145460, dtype: object

# %%
#12. Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row,
# and store the value in this new column.
df["difference"]=df["maxtemp"]-df["mintemp"]
print(df['difference'])
df.columns
# Out:
# 0          9.5
# 1         17.7
# 2         12.8
# 3         18.8
# 4         14.8
#           ...
# 145455    20.6
# 145456    21.7
# 145457    21.5
# 145458    19.2
# 145459     NaN
# Name: difference, Length: 145460, dtype: float64
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow', 'difference'],
#       dtype='object')

# %%
#13. Remove the evaporation and sunshine columns from the dataset permanently.
print(df.columns)
df.drop(["evaporation","sunshine"],axis=1,inplace=True)
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow', 'difference'],
#       dtype='object')
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'windgustdir',
#        'windgustspeed', 'winddir9am', 'winddir3pm', 'windspeed9am',
#        'windspeed3pm', 'humidity9am', 'humidity3pm', 'pressure9am',
#        'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm',
#        'raintoday', 'raintomorrow', 'difference'],
#       dtype='object')
